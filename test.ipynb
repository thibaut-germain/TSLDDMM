# %%
from aeon.datasets import load_classification
import matplotlib.pyplot as plt
import numpy as np

# %%
multivariate_dataset_lst = [
    "Cricket", # Maybe keep few labels
    "ERing", #idem
    "Handwriting", #idem
    "Libras", #idem
    "NATOPS",
    "RacketSports",
    "UWaveGestureLibrary",
    "ArticularyWordRecognition", 
]

univariate_dataset_lst = [
    "ArrowHead", 
    "BME", 
    "ECG200",
    "FacesUCR",
    "GunPoint", 
    "PhalangesOutlinesCorrect",
    "Trace",
]

# %%
X,y = load_classification(name="BME",split="train")
print(X.shape)
fig,axs = plt.subplots(np.unique(y).shape[0],1)
for i, label in enumerate(np.unique(y)):
    for x in X[y==label]: 
        axs[i].plot(x.T,color="black",alpha=0.1)
# Out:
# (30, 1, 128)
